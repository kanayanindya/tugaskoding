# %% [markdown]
# buat variabel skalar x dan simpan suatu nilai skalar

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 70

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 20

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
print(f"hasil penjumlahan x+y adalah : {(x+y)}")
# Out:
# hasil penjumlahan x+y adalah : 90

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.75

# %%
# jumlahkan x_float dengan y
x_float + y
# Out:
# 20.75

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25) # dtype is optional
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=25>

# %%
y_tf = tf.Variable(10)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=35>

# %%
xysum = tf.add(x_tf, y_tf)
xysum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=35>

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
x_pt = torch.tensor(30)

# %%
type(x_pt)
# Out:
# torch.Tensor
